# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import json
from io import StringIO
import numpy as np
import matplotlib

# File to Load (Remember to Change These)
school_data = "INSchoolDataCopy.csv"
test_score_data = "SchoolCorpDataRefined.csv"
income_data = "IncomeUpdateRefined.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data)
test_score_data = pd.read_csv(test_score_data)
income_data = pd.read_csv(income_data)
# Combine the data into a single dataset
school_complete = pd.merge(school_data, test_score_data, how="left", on=["ID", "ID"])

# %%
school_complete
# Out:
#          ID                     District Name                Mailing Address  \
# 0    9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 1      15.0   ADAMS CENTRAL COMMUNITY SCHOOLS            222 W WASHINGTON ST
# 2    5265.0        ALEXANDRIA COM SCHOOL CORP            202 E WASHINGTON ST
# 3    5275.0    ANDERSON COMMUNITY SCHOOL CORP             1600 HILLCREST AVE
# 4    9790.0      ANDERSON PREPARATORY ACADEMY                 3205 W 25TH ST
# ..      ...                               ...                            ...
# 403  8665.0           WHITLEY CO CONS SCHOOLS                107 N WALNUT ST
# 404  9540.0         WILSON EDUCATION CTR CORP                     PO BOX 217
# 405  9845.0       XAVIER SCHOOL OF EXCELLENCE     850 W JACKSON BLVD STE 850
# 406  1910.0        YORKTOWN COMMUNITY SCHOOLS             2311 S BROADWAY ST
# 407   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
#
#               City State    ZIP  Overall Points Overall Grade
# 0     INDIANAPOLIS    IN  46204             NaN           NaN
# 1           MONROE    IN  46772            87.2             B
# 2       ALEXANDRIA    IN  46001            73.2             C
# 3         ANDERSON    IN  46011            72.4             C
# 4         ANDERSON    IN  46011             NaN           NaN
# ..             ...   ...    ...             ...           ...
# 403  COLUMBIA CITY    IN  46725            81.7             B
# 404    CHARLESTOWN    IN  47111             NaN           NaN
# 405        CHICAGO    IN  60607             NaN           NaN
# 406       YORKTOWN    IN  47396            86.3             B
# 407     ZIONSVILLE    IN  46077            94.7             A
#
# [408 rows x 8 columns]

# %%
school_income_complete = pd.merge(school_complete, income_data, how="left", on=["ZIP", "ZIP"])
school_income_complete
# Out:
#           ID                     District Name                Mailing Address  \
# 0     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 1     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 2     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 3     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 4     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# ...      ...                               ...                            ...
# 2755   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2756   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2757   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2758   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2759   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
#
#               City State    ZIP  Overall Points Overall Grade  \
# 0     INDIANAPOLIS    IN  46204             NaN           NaN
# 1     INDIANAPOLIS    IN  46204             NaN           NaN
# 2     INDIANAPOLIS    IN  46204             NaN           NaN
# 3     INDIANAPOLIS    IN  46204             NaN           NaN
# 4     INDIANAPOLIS    IN  46204             NaN           NaN
# ...            ...   ...    ...             ...           ...
# 2755    ZIONSVILLE    IN  46077            94.7             A
# 2756    ZIONSVILLE    IN  46077            94.7             A
# 2757    ZIONSVILLE    IN  46077            94.7             A
# 2758    ZIONSVILLE    IN  46077            94.7             A
# 2759    ZIONSVILLE    IN  46077            94.7             A
#
#      Adjust Gross Income Number of returns   Amount
# 0                551,529             4,150  559,279
# 1                  13284              1020    13635
# 2                  37721               990    38523
# 3                  50494               830    51224
# 4                  33246               390    33575
# ...                  ...               ...      ...
# 2755               57939              1560    59367
# 2756               81710              1320    83411
# 2757               99923              1140   101389
# 2758              513353              3560   520606
# 2759             1784854              3390  1817916
#
# [2760 rows x 11 columns]

# %%
school_income_complete
# Out:
#           ID                     District Name                Mailing Address  \
# 0     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 1     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 2     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 3     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# 4     9545.0  21ST CENTURY CHARTER SCH OF GARY  333 N PENNSYLVANIA SUITE 1000
# ...      ...                               ...                            ...
# 2755   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2756   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2757   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2758   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
# 2759   630.0      ZIONSVILLE COMMUNITY SCHOOLS                900 MULBERRY ST
#
#               City State    ZIP  Overall Points Overall Grade  \
# 0     INDIANAPOLIS    IN  46204             NaN           NaN
# 1     INDIANAPOLIS    IN  46204             NaN           NaN
# 2     INDIANAPOLIS    IN  46204             NaN           NaN
# 3     INDIANAPOLIS    IN  46204             NaN           NaN
# 4     INDIANAPOLIS    IN  46204             NaN           NaN
# ...            ...   ...    ...             ...           ...
# 2755    ZIONSVILLE    IN  46077            94.7             A
# 2756    ZIONSVILLE    IN  46077            94.7             A
# 2757    ZIONSVILLE    IN  46077            94.7             A
# 2758    ZIONSVILLE    IN  46077            94.7             A
# 2759    ZIONSVILLE    IN  46077            94.7             A
#
#      Adjust Gross Income Number of returns   Amount
# 0                551,529             4,150  559,279
# 1                  13284              1020    13635
# 2                  37721               990    38523
# 3                  50494               830    51224
# 4                  33246               390    33575
# ...                  ...               ...      ...
# 2755               57939              1560    59367
# 2756               81710              1320    83411
# 2757               99923              1140   101389
# 2758              513353              3560   520606
# 2759             1784854              3390  1817916
#
# [2760 rows x 11 columns]

# %%
school_district = school_income_complete.dropna()

# %%
school_district.dtypes
# Out:
# ID                     float64
# District Name           object
# Mailing Address         object
# City                    object
# State                   object
# ZIP                      int64
# Overall Points         float64
# Overall Grade           object
# Adjust Gross Income     object
# Number of returns       object
# Amount                  object
# dtype: object

# %%
school_district['Amount'] = pd.to_numeric(school_district['Amount'], errors='coerce')
# Out:
# /Users/matthouser/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
school_district['Amount'].dtype
# Out:
# dtype('float64')

# %%
school_district['Adjust Gross Income'] = pd.to_numeric(school_district['Adjust Gross Income'], errors='coerce')
# Out:
# /Users/matthouser/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
school_district['Adjust Gross Income'].dtype
# Out:
# dtype('float64')

# %%
school_district['Number of returns'] = pd.to_numeric(school_district['Number of returns'], errors='coerce')
# Out:
# /Users/matthouser/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
school_district.dtypes
# Out:
# ID                     float64
# District Name           object
# Mailing Address         object
# City                    object
# State                   object
# ZIP                      int64
# Overall Points         float64
# Overall Grade           object
# Adjust Gross Income    float64
# Number of returns      float64
# Amount                 float64
# dtype: object

# %%
school_district
# Out:
#          ID                    District Name      Mailing Address        City  \
# 7      15.0  ADAMS CENTRAL COMMUNITY SCHOOLS  222 W WASHINGTON ST      MONROE
# 8      15.0  ADAMS CENTRAL COMMUNITY SCHOOLS  222 W WASHINGTON ST      MONROE
# 9      15.0  ADAMS CENTRAL COMMUNITY SCHOOLS  222 W WASHINGTON ST      MONROE
# 10     15.0  ADAMS CENTRAL COMMUNITY SCHOOLS  222 W WASHINGTON ST      MONROE
# 11     15.0  ADAMS CENTRAL COMMUNITY SCHOOLS  222 W WASHINGTON ST      MONROE
# ...     ...                              ...                  ...         ...
# 2755  630.0     ZIONSVILLE COMMUNITY SCHOOLS      900 MULBERRY ST  ZIONSVILLE
# 2756  630.0     ZIONSVILLE COMMUNITY SCHOOLS      900 MULBERRY ST  ZIONSVILLE
# 2757  630.0     ZIONSVILLE COMMUNITY SCHOOLS      900 MULBERRY ST  ZIONSVILLE
# 2758  630.0     ZIONSVILLE COMMUNITY SCHOOLS      900 MULBERRY ST  ZIONSVILLE
# 2759  630.0     ZIONSVILLE COMMUNITY SCHOOLS      900 MULBERRY ST  ZIONSVILLE
#
#      State    ZIP  Overall Points Overall Grade  Adjust Gross Income  \
# 7       IN  46772            87.2             B                  NaN
# 8       IN  46772            87.2             B               5552.0
# 9       IN  46772            87.2             B              14219.0
# 10      IN  46772            87.2             B              10530.0
# 11      IN  46772            87.2             B               9735.0
# ...    ...    ...             ...           ...                  ...
# 2755    IN  46077            94.7             A              57939.0
# 2756    IN  46077            94.7             A              81710.0
# 2757    IN  46077            94.7             A              99923.0
# 2758    IN  46077            94.7             A             513353.0
# 2759    IN  46077            94.7             A            1784854.0
#
#       Number of returns     Amount
# 7                   NaN        NaN
# 8                 460.0     5574.0
# 9                 400.0    14334.0
# 10                170.0    10631.0
# 11                110.0     9830.0
# ...                 ...        ...
# 2755             1560.0    59367.0
# 2756             1320.0    83411.0
# 2757             1140.0   101389.0
# 2758             3560.0   520606.0
# 2759             3390.0  1817916.0
#
# [1813 rows x 11 columns]

# %%
school_district.groupby('ID').mean()[['Overall Points', 'Adjust Gross Income']]
# Out:
#         Overall Points  Adjust Gross Income
# ID
# 15.0              87.2         11756.400000
# 25.0              86.4         78662.500000
# 35.0              90.3         27757.833333
# 125.0             93.3        205356.500000
# 235.0             77.3         28598.666667
# ...                ...                  ...
# 8525.0            90.1          4251.400000
# 8535.0            88.9          8219.400000
# 8565.0            83.9         63622.500000
# 8625.0            82.8         36448.166667
# 8665.0            81.7        112163.333333
#
# [259 rows x 2 columns]

# %%
table = pd.pivot_table(school_district, values=['Overall Points', 'Number of returns', 'Adjust Gross Income'], index=['District Name', 'City', 'State', 'ZIP', 'Overall Grade'],
                      aggfunc={'Overall Points': np.mean,
                               'Number of returns': np.sum, 
                               'Adjust Gross Income': [np.median, np.sum]})  
                               
                              
table
# Out:
#                                                                         Adjust Gross Income  \
#                                                                                      median
# District Name                   City          State ZIP   Overall Grade
# ADAMS CENTRAL COMMUNITY SCHOOLS MONROE        IN    46772 B                         10530.0
# ALEXANDRIA COM SCHOOL CORP      ALEXANDRIA    IN    46001 C                         43256.0
# ANDERSON COMMUNITY SCHOOL CORP  ANDERSON      IN    46011 C                         72958.5
# ARGOS COMMUNITY SCHOOLS         ARGOS         IN    46501 B                         16112.0
# ATTICA CONSOLIDATED SCH CORP    ATTICA        IN    47918 C                         25679.0
# ...                                                                                     ...
# WHITING SCHOOL CITY             WHITING       IN    46394 B                         49138.0
# WHITKO COMMUNITY SCHOOL CORP    PIERCETON     IN    46562 C                         20914.0
# WHITLEY CO CONS SCHOOLS         COLUMBIA CITY IN    46725 B                        108188.5
# YORKTOWN COMMUNITY SCHOOLS      YORKTOWN      IN    47396 B                         30624.0
# ZIONSVILLE COMMUNITY SCHOOLS    ZIONSVILLE    IN    46077 A                         90816.5
#
#                                                                                     \
#                                                                                sum
# District Name                   City          State ZIP   Overall Grade
# ADAMS CENTRAL COMMUNITY SCHOOLS MONROE        IN    46772 B                58782.0
# ALEXANDRIA COM SCHOOL CORP      ALEXANDRIA    IN    46001 C               232301.0
# ANDERSON COMMUNITY SCHOOL CORP  ANDERSON      IN    46011 C               453901.0
# ARGOS COMMUNITY SCHOOLS         ARGOS         IN    46501 B                75693.0
# ATTICA CONSOLIDATED SCH CORP    ATTICA        IN    47918 C               137011.0
# ...                                                                            ...
# WHITING SCHOOL CITY             WHITING       IN    46394 B               263552.0
# WHITKO COMMUNITY SCHOOL CORP    PIERCETON     IN    46562 C               119581.0
# WHITLEY CO CONS SCHOOLS         COLUMBIA CITY IN    46725 B               672980.0
# YORKTOWN COMMUNITY SCHOOLS      YORKTOWN      IN    47396 B               266084.0
# ZIONSVILLE COMMUNITY SCHOOLS    ZIONSVILLE    IN    46077 A              2568102.0
#
#                                                                         Number of returns  \
#                                                                                       sum
# District Name                   City          State ZIP   Overall Grade
# ADAMS CENTRAL COMMUNITY SCHOOLS MONROE        IN    46772 B                        1240.0
# ALEXANDRIA COM SCHOOL CORP      ALEXANDRIA    IN    46001 C                        4910.0
# ANDERSON COMMUNITY SCHOOL CORP  ANDERSON      IN    46011 C                        8270.0
# ARGOS COMMUNITY SCHOOLS         ARGOS         IN    46501 B                        1700.0
# ATTICA CONSOLIDATED SCH CORP    ATTICA        IN    47918 C                        2810.0
# ...                                                                                   ...
# WHITING SCHOOL CITY             WHITING       IN    46394 B                        5590.0
# WHITKO COMMUNITY SCHOOL CORP    PIERCETON     IN    46562 C                        2330.0
# WHITLEY CO CONS SCHOOLS         COLUMBIA CITY IN    46725 B                       11730.0
# YORKTOWN COMMUNITY SCHOOLS      YORKTOWN      IN    47396 B                        3510.0
# ZIONSVILLE COMMUNITY SCHOOLS    ZIONSVILLE    IN    46077 A                       14420.0
#
#                                                                         Overall Points
#                                                                                   mean
# District Name                   City          State ZIP   Overall Grade
# ADAMS CENTRAL COMMUNITY SCHOOLS MONROE        IN    46772 B                       87.2
# ALEXANDRIA COM SCHOOL CORP      ALEXANDRIA    IN    46001 C                       73.2
# ANDERSON COMMUNITY SCHOOL CORP  ANDERSON      IN    46011 C                       72.4
# ARGOS COMMUNITY SCHOOLS         ARGOS         IN    46501 B                       80.4
# ATTICA CONSOLIDATED SCH CORP    ATTICA        IN    47918 C                       79.4
# ...                                                                                ...
# WHITING SCHOOL CITY             WHITING       IN    46394 B                       80.1
# WHITKO COMMUNITY SCHOOL CORP    PIERCETON     IN    46562 C                       79.4
# WHITLEY CO CONS SCHOOLS         COLUMBIA CITY IN    46725 B                       81.7
# YORKTOWN COMMUNITY SCHOOLS      YORKTOWN      IN    47396 B                       86.3
# ZIONSVILLE COMMUNITY SCHOOLS    ZIONSVILLE    IN    46077 A                       94.7
#
# [259 rows x 4 columns]

# %%
#Narrowed data to test scores in each zip
test_score_table = pd.pivot_table(school_district, values=['Overall Points'], index=['City','State','ZIP','District Name','Overall Grade'])  
test_score_table = test_score_table.reset_index()
test_score_table
# Out:
#            City State    ZIP                   District Name Overall Grade  \
# 0         AKRON    IN  46910   TIPPECANOE VALLEY SCHOOL CORP             B
# 1        ALBION    IN  46701   CENTRAL NOBLE COM SCHOOL CORP             C
# 2    ALEXANDRIA    IN  46001      ALEXANDRIA COM SCHOOL CORP             C
# 3      ANDERSON    IN  46011  ANDERSON COMMUNITY SCHOOL CORP             C
# 4      ANDERSON    IN  46011   FRANKTON-LAPEL COMMUNITY SCHS             B
# ..          ...   ...    ...                             ...           ...
# 254     WINAMAC    IN  46996    EASTERN PULASKI COM SCH CORP             B
# 255  WINCHESTER    IN  47394    RANDOLPH CENTRAL SCHOOL CORP             B
# 256     WOLCOTT    IN  47995          TRI-COUNTY SCHOOL CORP             B
# 257    YORKTOWN    IN  47396      YORKTOWN COMMUNITY SCHOOLS             B
# 258  ZIONSVILLE    IN  46077    ZIONSVILLE COMMUNITY SCHOOLS             A
#
#      Overall Points
# 0              83.6
# 1              76.3
# 2              73.2
# 3              72.4
# 4              82.7
# ..              ...
# 254            83.0
# 255            82.9
# 256            88.9
# 257            86.3
# 258            94.7
#
# [259 rows x 6 columns]

# %%
#Average Test Scores by Zip
average_points = test_score_table.groupby(["Overall Points"])
average_comparison = average_points.mean()
average_comparison = average_comparison.reset_index()
average_comparison
# Out:
#      Overall Points      ZIP
# 0              59.3  47520.0
# 1              64.7  46204.0
# 2              65.1  47358.0
# 3              67.7  47260.0
# 4              68.3  46036.0
# ..              ...      ...
# 144            96.6  46117.0
# 145            96.8  46168.0
# 146            98.3  46033.0
# 147            99.0  46112.0
# 148           100.2  47558.0
#
# [149 rows x 2 columns]

# %%
#Worst Average
worst_average_score = average_comparison.loc[0, :]
worst_average_score
# Out:
# Overall Points       59.3
# ZIP               47520.0
# Name: 0, dtype: float64

# %%
#Best Average
best_average_score = average_comparison.loc[120,:]
best_average_score
# Out:
# Overall Points       90.60
# ZIP               46749.25
# Name: 120, dtype: float64

# %%
#All school with test scores over 90
over_ninety = test_score_table.loc[test_score_table["Overall Points"] > 90, [
    "Overall Points","City", "State", "ZIP", "District Name"]]
over_ninety
# Out:
#      Overall Points             City State    ZIP  \
# 13             90.8       BATESVILLE    IN  47006
# 16             90.3            BERNE    IN  46711
# 20             90.6      BLOOMINGTON    IN  47401
# 22             96.4          BOURBON    IN  46504
# 26             99.0       BROWNSBURG    IN  46112
# 29             90.4           BUTLER    IN  46721
# 32             98.3           CARMEL    IN  46033
# 36             90.1         CHALMERS    IN  47929
# 37             96.6  CHARLOTTESVILLE    IN  46117
# 38             90.6       CHESTERTON    IN  46304
# 48             93.8          CORYDON    IN  47112
# 56             93.1         DANVILLE    IN  46122
# 60             92.7           DUBOIS    IN  47527
# 64             94.2     ELLETTSVILLE    IN  47429
# 65             91.4           ELNORA    IN  47529
# 73             93.3       FORT WAYNE    IN  46814
# 74             90.5        FORTVILLE    IN  46040
# 94             90.6        GREENTOWN    IN  46936
# 96             92.9        GREENWOOD    IN  46143
# 127            90.9            KOUTS    IN  46347
# 136            90.5     LAWRENCEBURG    IN  47025
# 138            92.0          LEOPOLD    IN  47551
# 142            90.5           LIZTON    IN  46149
# 145            90.6           LOWELL    IN  46356
# 157            91.8        MISHAWAKA    IN  46545
# 163           100.2       MONTGOMERY    IN  47558
# 167            92.2     MOUNT VERNON    IN  47620
# 171            95.7          MUNSTER    IN  46321
# 173            90.8         NAPPANEE    IN  46550
# 179            91.1      NOBLESVILLE    IN  46060
# 193            96.8       PLAINFIELD    IN  46168
# 198            92.0       POSEYVILLE    IN  47633
# 206            91.2        ROSSVILLE    IN  46065
# 209            92.3      RUSSIAVILLE    IN  46979
# 219            94.5      SHELBYVILLE    IN  46176
# 220            91.7         SHERIDAN    IN  46069
# 222            96.4         SPEEDWAY    IN  46224
# 224            91.1          ST LEON    IN  47012
# 228            90.2        TELL CITY    IN  47586
# 231            94.2           TOPEKA    IN  46571
# 236            93.4       VALPARAISO    IN  46385
# 237            92.1       VALPARAISO    IN  46385
# 248            95.8   WEST LAFAYETTE    IN  47906
# 258            94.7       ZIONSVILLE    IN  46077
#
#                           District Name
# 13        BATESVILLE COMMUNITY SCH CORP
# 16                  SOUTH ADAMS SCHOOLS
# 20           MONROE COUNTY COM SCH CORP
# 22            TRITON SCHOOL CORPORATION
# 26        BROWNSBURG COMMUNITY SCH CORP
# 29       DEKALB CO EASTERN COM SCH DIST
# 32                  CARMEL CLAY SCHOOLS
# 36          FRONTIER SCHOOL CORPORATION
# 37      EASTERN HANCOCK CO COM SCH CORP
# 38          DUNELAND SCHOOL CORPORATION
# 48           SOUTH HARRISON COM SCHOOLS
# 56       DANVILLE COMMUNITY SCHOOL CORP
# 60         NORTHEAST DUBOIS CO SCH CORP
# 64          RICHLAND-BEAN BLOSSOM C S C
# 65            NORTH DAVIESS COM SCHOOLS
# 73   M S D SOUTHWEST ALLEN COUNTY SCHLS
# 74         MT VERNON COMMUNITY SCH CORP
# 94           EASTERN HOWARD SCHOOL CORP
# 96            CENTER GROVE COM SCH CORP
# 127      EAST PORTER COUNTY SCHOOL CORP
# 136        LAWRENCEBURG COM SCHOOL CORP
# 138      PERRY CENTRAL COM SCHOOLS CORP
# 142        NORTH WEST HENDRICKS SCHOOLS
# 145        TRI-CREEK SCHOOL CORPORATION
# 157        PENN-HARRIS-MADISON SCH CORP
# 163          BARR-REEVE COM SCHOOLS INC
# 167                  M S D MOUNT VERNON
# 171              SCHOOL TOWN OF MUNSTER
# 173            WA-NEE COMMUNITY SCHOOLS
# 179                 NOBLESVILLE SCHOOLS
# 193       PLAINFIELD COMMUNITY SCH CORP
# 198        M S D NORTH POSEY CO SCHOOLS
# 206       ROSSVILLE CON SCHOOL DISTRICT
# 209                 WESTERN SCHOOL CORP
# 219      SOUTHWESTERN CON SCH SHELBY CO
# 220          SHERIDAN COMMUNITY SCHOOLS
# 222             SCHOOL TOWN OF SPEEDWAY
# 224        SUNMAN-DEARBORN COM SCH CORP
# 228      TELL CITY-TROY TWP SCHOOL CORP
# 231         WESTVIEW SCHOOL CORPORATION
# 236          UNION TOWNSHIP SCHOOL CORP
# 237        VALPARAISO COMMUNITY SCHOOLS
# 248      WEST LAFAYETTE COM SCHOOL CORP
# 258        ZIONSVILLE COMMUNITY SCHOOLS

# %%
#All school with test scores over 80
over_eighty = test_score_table.loc[test_score_table["Overall Points"] > 80, [
    "Overall Points","City", "State", "ZIP", "District Name"]]
over_eighty
# Out:
#      Overall Points        City State    ZIP                  District Name
# 0              83.6       AKRON    IN  46910  TIPPECANOE VALLEY SCHOOL CORP
# 4              82.7    ANDERSON    IN  46011  FRANKTON-LAPEL COMMUNITY SCHS
# 5              84.7      ANGOLA    IN  46703           M S D STEUBEN COUNTY
# 6              86.0     ARCADIA    IN  46030   HAMILTON HEIGHTS SCHOOL CORP
# 7              80.4       ARGOS    IN  46501        ARGOS COMMUNITY SCHOOLS
# ..              ...         ...   ...    ...                            ...
# 254            83.0     WINAMAC    IN  46996   EASTERN PULASKI COM SCH CORP
# 255            82.9  WINCHESTER    IN  47394   RANDOLPH CENTRAL SCHOOL CORP
# 256            88.9     WOLCOTT    IN  47995         TRI-COUNTY SCHOOL CORP
# 257            86.3    YORKTOWN    IN  47396     YORKTOWN COMMUNITY SCHOOLS
# 258            94.7  ZIONSVILLE    IN  46077   ZIONSVILLE COMMUNITY SCHOOLS
#
# [192 rows x 5 columns]

# %%
#All school with test scores over 70
over_seventy = test_score_table.loc[test_score_table["Overall Points"] > 70, [
    "Overall Points","City", "State", "ZIP", "District Name"]]
over_seventy
# Out:
#      Overall Points        City State    ZIP                   District Name
# 0              83.6       AKRON    IN  46910   TIPPECANOE VALLEY SCHOOL CORP
# 1              76.3      ALBION    IN  46701   CENTRAL NOBLE COM SCHOOL CORP
# 2              73.2  ALEXANDRIA    IN  46001      ALEXANDRIA COM SCHOOL CORP
# 3              72.4    ANDERSON    IN  46011  ANDERSON COMMUNITY SCHOOL CORP
# 4              82.7    ANDERSON    IN  46011   FRANKTON-LAPEL COMMUNITY SCHS
# ..              ...         ...   ...    ...                             ...
# 254            83.0     WINAMAC    IN  46996    EASTERN PULASKI COM SCH CORP
# 255            82.9  WINCHESTER    IN  47394    RANDOLPH CENTRAL SCHOOL CORP
# 256            88.9     WOLCOTT    IN  47995          TRI-COUNTY SCHOOL CORP
# 257            86.3    YORKTOWN    IN  47396      YORKTOWN COMMUNITY SCHOOLS
# 258            94.7  ZIONSVILLE    IN  46077    ZIONSVILLE COMMUNITY SCHOOLS
#
# [253 rows x 5 columns]

# %%
#All scores under 70
under_seventy = test_score_table.loc[test_score_table["Overall Points"] < 70, [
    "Overall Points","City", "State", "ZIP", "District Name"]]
under_seventy
# Out:
#      Overall Points          City State    ZIP                 District Name
# 31             59.3     CANNELTON    IN  47520        CANNELTON CITY SCHOOLS
# 66             68.3        ELWOOD    IN  46036  ELWOOD COMMUNITY SCHOOL CORP
# 110            64.7  INDIANAPOLIS    IN  46204   INDIANAPOLIS PUBLIC SCHOOLS
# 111            69.0  INDIANAPOLIS    IN  46219         M S D WARREN TOWNSHIP
# 151            67.7        MEDORA    IN  47260  MEDORA COMMUNITY SCHOOL CORP
# 159            65.1         MODOC    IN  47358      UNION SCHOOL CORPORATION

# %%
import matplotlib.pyplot as plt
under_seventy.plot(kind='bar')
plt.figure(figsize=(8000.0,300.0))
plt.show()

# %%
#Lowest and Highest Overall Score
lowest_score = test_score_table["Overall Points"].min()
lowest_score
highest_score = test_score_table["Overall Points"].max()
highest_score

summary_table = pd.DataFrame({"Highest Test Score": [highest_score],
                              "Lowest Test Score": [lowest_score]})
summary_table
#Need to get the city/state/zip included
# Out:
#    Highest Test Score  Lowest Test Score
# 0               100.2               59.3

# %%
#Average Scores for each Zip Code
zip_code_group = test_score_table.groupby('ZIP').mean()["Overall Points"]
zip_code_group = zip_code_group.reset_index()
zip_code_group
# Out:
#        ZIP  Overall Points
# 0    46001           73.20
# 1    46011           77.55
# 2    46030           86.00
# 3    46033           98.30
# 4    46036           68.30
# ..     ...             ...
# 240  47963           79.80
# 241  47978           86.20
# 242  47987           87.20
# 243  47993           84.00
# 244  47995           88.90
#
# [245 rows x 2 columns]

# %%
#Chart 0-75, <85, <95, >95
zip_code_group = zip_code_group[zip_code_group['Overall Points']> 90].groupby('ZIP')
zip_code_group.describe()
# Out:
#       Overall Points                                                      \
#                count        mean std         min         25%         50%
# ZIP
# 46033            1.0   98.300000 NaN   98.300000   98.300000   98.300000
# 46040            1.0   90.500000 NaN   90.500000   90.500000   90.500000
# 46060            1.0   91.100000 NaN   91.100000   91.100000   91.100000
# 46065            1.0   91.200000 NaN   91.200000   91.200000   91.200000
# 46069            1.0   91.700000 NaN   91.700000   91.700000   91.700000
# 46077            1.0   94.700000 NaN   94.700000   94.700000   94.700000
# 46112            1.0   99.000000 NaN   99.000000   99.000000   99.000000
# 46117            1.0   96.600000 NaN   96.600000   96.600000   96.600000
# 46122            1.0   93.100000 NaN   93.100000   93.100000   93.100000
# 46143            1.0   92.900000 NaN   92.900000   92.900000   92.900000
# 46149            1.0   90.500000 NaN   90.500000   90.500000   90.500000
# 46168            1.0   96.800000 NaN   96.800000   96.800000   96.800000
# 46224            1.0   96.400000 NaN   96.400000   96.400000   96.400000
# 46304            1.0   90.600000 NaN   90.600000   90.600000   90.600000
# 46321            1.0   95.700000 NaN   95.700000   95.700000   95.700000
# 46347            1.0   90.900000 NaN   90.900000   90.900000   90.900000
# 46356            1.0   90.600000 NaN   90.600000   90.600000   90.600000
# 46385            1.0   90.566667 NaN   90.566667   90.566667   90.566667
# 46504            1.0   96.400000 NaN   96.400000   96.400000   96.400000
# 46545            1.0   91.800000 NaN   91.800000   91.800000   91.800000
# 46550            1.0   90.800000 NaN   90.800000   90.800000   90.800000
# 46571            1.0   94.200000 NaN   94.200000   94.200000   94.200000
# 46711            1.0   90.300000 NaN   90.300000   90.300000   90.300000
# 46721            1.0   90.400000 NaN   90.400000   90.400000   90.400000
# 46814            1.0   93.300000 NaN   93.300000   93.300000   93.300000
# 46936            1.0   90.600000 NaN   90.600000   90.600000   90.600000
# 46979            1.0   92.300000 NaN   92.300000   92.300000   92.300000
# 47006            1.0   90.800000 NaN   90.800000   90.800000   90.800000
# 47025            1.0   90.500000 NaN   90.500000   90.500000   90.500000
# 47112            1.0   93.800000 NaN   93.800000   93.800000   93.800000
# 47401            1.0   90.600000 NaN   90.600000   90.600000   90.600000
# 47429            1.0   94.200000 NaN   94.200000   94.200000   94.200000
# 47527            1.0   92.700000 NaN   92.700000   92.700000   92.700000
# 47529            1.0   91.400000 NaN   91.400000   91.400000   91.400000
# 47551            1.0   92.000000 NaN   92.000000   92.000000   92.000000
# 47558            1.0  100.200000 NaN  100.200000  100.200000  100.200000
# 47586            1.0   90.200000 NaN   90.200000   90.200000   90.200000
# 47620            1.0   92.200000 NaN   92.200000   92.200000   92.200000
# 47633            1.0   92.000000 NaN   92.000000   92.000000   92.000000
# 47906            1.0   95.800000 NaN   95.800000   95.800000   95.800000
# 47929            1.0   90.100000 NaN   90.100000   90.100000   90.100000
#
#
#               75%         max
# ZIP
# 46033   98.300000   98.300000
# 46040   90.500000   90.500000
# 46060   91.100000   91.100000
# 46065   91.200000   91.200000
# 46069   91.700000   91.700000
# 46077   94.700000   94.700000
# 46112   99.000000   99.000000
# 46117   96.600000   96.600000
# 46122   93.100000   93.100000
# 46143   92.900000   92.900000
# 46149   90.500000   90.500000
# 46168   96.800000   96.800000
# 46224   96.400000   96.400000
# 46304   90.600000   90.600000
# 46321   95.700000   95.700000
# 46347   90.900000   90.900000
# 46356   90.600000   90.600000
# 46385   90.566667   90.566667
# 46504   96.400000   96.400000
# 46545   91.800000   91.800000
# 46550   90.800000   90.800000
# 46571   94.200000   94.200000
# 46711   90.300000   90.300000
# 46721   90.400000   90.400000
# 46814   93.300000   93.300000
# 46936   90.600000   90.600000
# 46979   92.300000   92.300000
# 47006   90.800000   90.800000
# 47025   90.500000   90.500000
# 47112   93.800000   93.800000
# 47401   90.600000   90.600000
# 47429   94.200000   94.200000
# 47527   92.700000   92.700000
# 47529   91.400000   91.400000
# 47551   92.000000   92.000000
# 47558  100.200000  100.200000
# 47586   90.200000   90.200000
# 47620   92.200000   92.200000
# 47633   92.000000   92.000000
# 47906   95.800000   95.800000
# 47929   90.100000   90.100000

# %%
#Bar Chart
import matplotlib.pyplot as plt
zip_code_group.plot(kind='bar')
plt.figure(figsize=(8000.0,300.0))
plt.show()

# %%
#Scatter Plot
zip_code = zip_code_group.index
zip_code
grades_by_zip = zip_code_group['Overall Points']
plt.scatter(zip_code,grades_by_zip)

# %%
#Map based on zip coordinates
#create poppa for each map
#http://geopandas.org/geocoding.html
#https://matplotlib.org/gallery/index.html (charts)
